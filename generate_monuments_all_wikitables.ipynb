# %%
import pandas as pd # Beautiful tool for data wrangling! e.g. '!pip install pandas' from a Notebook
# See https://mariadb.com/blog/how-connect-python-programs-mariadb e.g. '!pip install mysql' from Notebook
import MySQLdb 
import re
from collections import Counter
import os
from collections import OrderedDict
import random

pd.set_option("display.max_rows",35) # Useful when having large Pandas DataFrames like we do here

# %%
conn = MySQLdb.connect(user='mos', passwd='', db='monuments_db')
cursor = conn.cursor()

# %% [markdown]
# ## Monuments_all

# %%
# Load full table into memory
sql = "SELECT * FROM monuments_all"
df = pd.io.sql.read_sql(conn.escape_string(sql), conn)

# %%
list(df.keys())
# Out:
# ['country',
#  'lang',
#  'project',
#  'id',
#  'adm0',
#  'adm1',
#  'adm2',
#  'adm3',
#  'adm4',
#  'name',
#  'address',
#  'municipality',
#  'lat',
#  'lon',
#  'lat_int',
#  'lon_int',
#  'image',
#  'commonscat',
#  'source',
#  'changed',
#  'monument_article',
#  'registrant_url']

# %%
country_codes = dict(df.country.value_counts()).keys()
print(len(country_codes))
print(country_codes)
# Out:
# 77
# dict_keys(['be-wal', 'bo', 'us', 'gb-sct', 'nl-prov', 'de-he', 'tn', 'pa', 'ch', 'aq', 'dk-bygning', 'be-vlg', 'az', 'ca', 'se-arbetsl', 'it-88', 'hk', 'cz', 'no', 'at', 've', 'fr-object', 'in', 'be-bru', 'se-fornmin', 'dk-fortids', 'lu', 'nl-gem', 'ad', 'se-bbr', 'gb-eng', 'de-nrw-bm', 'gh', 'cm', 'it', 'cl', 'us-ca', 'ro', 'pt', 'am', 'nl-aw', 'il', 'pk', 'jo', 'ch-old', 'cn', 'gb-wls', 'ua', 'ru', 'nl', 'th', 'fr', 'uy', 'za', 'sv', 'it-bz', 'ph', 'es', 'de-by', 'dz', 'se-ship', 'ke', 'mt', 'ee', 'co', 'rs', 'ar', 'pl', 'by', 'ie', 'np', 'hu', 'jp-nhs', 'mx', 'de-nrw-k', 'sk', 'gb-nir'])

# %%
for code in country_codes:
    country = df[df["country"] == code]
    columns = country.columns
    for column in columns:
        values = country[column]
        sample = values.sample(n=10)
        examples = sample.values
        #print(code, column, values.sample(n=3))
        print(list(examples))
# Out:
# ['be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal']
# ['nl', 'fr', 'fr', 'fr', 'fr', 'en', 'en', 'nl', 'en', 'nl']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['57081-CLT-0146-01', '61031-CLT-0015-01', '92035-CLT-0007-01', '57081-CLT-0291-01', '62063-CLT-0031-01', '63023-CLT-0082-01', '53020-CLT-0001-01', '62009-PEX-0002-01', '25023-PEX-0001-01', '61079-CLT-0003-01']
# ['be', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'be']
# ['be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal', 'be-wal']
# ['', '', '', '', 'be-wht', '', '', 'be-wlg', 'be-wlg', 'be-wlg']
# [numpy.datetime64('2016-06-08T10:19:34.000000000+0200'), numpy.datetime64('2016-06-08T10:17:21.000000000+0200'), numpy.datetime64('2016-06-08T10:20:43.000000000+0200'), numpy.datetime64('2016-06-08T16:42:06.000000000+0200'), numpy.datetime64('2016-06-08T15:54:26.000000000+0200'), numpy.datetime64('2016-06-08T16:42:19.000000000+0200'), numpy.datetime64('2016-06-08T15:54:20.000000000+0200'), numpy.datetime64('2016-06-08T16:43:31.000000000+0200'), numpy.datetime64('2016-06-08T10:20:09.000000000+0200'), numpy.datetime64('2016-06-08T10:18:34.000000000+0200')]
# ['', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '']
# ['bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo']
# ['es', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'es']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['N/00-026', 'L/00-072', 'L/00-141', 'C/00-012', 'L/00-201', 'C/00-153', 'C/00-124', 'L/00-014', 'N/00-019', 'H/00-168']
# ['bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo', 'bo']
# ['bo-h', 'bo-h', 'bo-l', 'bo-c', 'bo-o', 'bo-l', 'bo-l', 'bo-h', 'bo-o', 'bo-l']
# ['[[Cochabamba]]', 'Sucre', '[[Potosí]]', 'Sucre', '[[La Paz]]', '[[Cochabamba]]', '[[La Paz]]', '[[Potosí]]', '[[La Paz]]', '[[Cochabamba]]']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['Conv. de San Agustín de Challacollo', 'Vivienda Comercio calle Jordán', '', 'Eduardo Avaroa', 'Sinagoga Judía', 'Casa del Cabildo - Plaza San Sebastian', 'C. Ravelo # 327', 'Iglesia de San Antonio de Padua', 'Casa del arquitecto', 'Ruinas Arqueológicas de la Isla Pachiri']
# ['Avenida 9 de Febrero', 'Avenida Aroma, frente calle Junín (Plaza San Sebastián)', 'Av. Camacho esq. calle Loayza', 'Calle Quijarro esquina calle Bolívar', 'Provincia Ingavi, Tiahuanacu', 'Calle Bustillos # 207 - 209', 'Calle Nicolás Ortíz # 109', 'Calle Junín, entre General Achá y Santivañez', 'Av. 6 de agosto y calle Belisario Salinas', 'Intersección de las avenidas: Irala, Omar Chávez Ortiz, Grigotá y Cañoto (sobre el primer anillo de circunvalación)']
# ['Sucre', '[[La Paz]]', 'Sucre', '[[La Paz]]', '[[Cochabamba]]', '[[Cochabamba]]', '[[Santísima Trinidad]]', '[[Cobija]]', '[[Cochabamba]]', '[[La Paz]]']
# [-17.390578000000001, -17.784901000000001, -16.501042000000002, -16.493152278, -17.396402999999999, nan, -16.527612999999999, -17.395568999999998, nan, -16.49361944]
# [-66.157116000000002, nan, nan, nan, nan, nan, -68.126205999999996, nan, -68.108233999999996, nan]
# [-348.0, nan, -330.0, nan, -348.0, -381.0, -330.0, nan, nan, -330.0]
# [nan, nan, -1363.0, nan, -1363.0, nan, -1323.0, -1264.0, -1363.0, -1323.0]
# ['', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', 'escultórico', '', '', '', '']
# ['//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_Cochabamba&oldid=90309882', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_La_Paz&oldid=86084083', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Tarija&oldid=69570108', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Potos%C3%AD&oldid=76887067', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Potos%C3%AD&oldid=76887067', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Chuquisaca&oldid=82590831', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Chuquisaca&oldid=82590831', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Chuquisaca&oldid=82590831', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_Potos%C3%AD&oldid=76887067', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_del_Departamento_de_La_Paz&oldid=86084083']
# [numpy.datetime64('2016-06-08T08:50:18.000000000+0200'), numpy.datetime64('2016-06-08T08:50:14.000000000+0200'), numpy.datetime64('2016-06-08T08:50:13.000000000+0200'), numpy.datetime64('2016-06-08T08:50:18.000000000+0200'), numpy.datetime64('2016-06-08T08:50:14.000000000+0200'), numpy.datetime64('2016-06-08T08:50:14.000000000+0200'), numpy.datetime64('2016-06-08T08:50:19.000000000+0200'), numpy.datetime64('2016-06-08T08:50:18.000000000+0200'), numpy.datetime64('2016-06-08T08:50:14.000000000+0200'), numpy.datetime64('2016-06-08T08:50:18.000000000+0200')]
# ['', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '']
# ['us', 'us', 'us', 'us', 'us', 'us', 'us', 'us', 'us', 'us']
# ['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['84000836', '71001032', '80002292', '87000325', '82004270', '88001588', '95000465', '66000670', '82002271', '78002844']
# ['us', 'us', 'us', 'us', 'us', 'us', 'us', 'us', 'us', 'us']
# ['us-mi', 'us-az', 'us-wa', 'us-dc', 'us-ia', 'us-oh', 'us-in', 'us-az', 'us-mo', 'us-ny']
# ['[[Wichita County, Texas]]', '[[Wabasha County, Minnesota]]', '[[Kent County, Rhode Island]]', '[[Androscoggin County, Maine]]', '[[Otsego County, New York]]', '[[Cuyahoga County, Ohio]]', '[[Wayne County, Pennsylvania]]', '[[Cobb County, Georgia]]', '[[Middlesex County, Massachusetts]]', '[[Lyon County, Kansas]]']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['[[Elisha Camp House|Elisha Camp House]]', '[[Basilica of St. Lawrence, Asheville|Church of St. Lawrence]]', '[[Rosenberg Library|Rosenberg Library]]', '[[Star Grange No. 9|Star Grange No. 9]]', '[[Somerville (Kenton, Delaware)|Somerville]]', '[[Chicano Park|Chicano Park]]', '[[Carleton Bridge|Carleton Bridge]]', '[[Common Burying Ground at Sandy Bank|Common Burying Ground at Sandy Bank]]', '[[Washington Avenue Historic District (Fredericksburg, Virginia)|Washington Avenue Historic District]]', '[[Clay County Courthouse (Illinois)|Clay County Courthouse]]']
# [numpy.datetime64('2016-06-08T11:21:47.000000000+0200'), numpy.datetime64('2016-06-08T11:22:09.000000000+0200'), numpy.datetime64('2016-06-08T11:18:23.000000000+0200'), numpy.datetime64('2016-06-08T11:46:18.000000000+0200'), numpy.datetime64('2016-06-08T11:54:04.000000000+0200'), numpy.datetime64('2016-06-08T11:54:32.000000000+0200'), numpy.datetime64('2016-06-08T11:37:09.000000000+0200'), numpy.datetime64('2016-06-08T11:27:29.000000000+0200'), numpy.datetime64('2016-06-08T11:19:25.000000000+0200'), numpy.datetime64('2016-06-08T11:18:24.000000000+0200')]
# ['Hanging_Rock_(Upper_Merion_Township,_Pennsylvania)', 'South_Union_Street_Historic_District_(Burlington,_Vermont)', 'Church_Hill_Grange_Hall', 'Webster_Methodist_Church', 'Saint_Paul_African_Union_Methodist_Church', 'West_Newark_Congregational_Church_and_Cemetery', 'Ole_Carlson_House', 'Scottsboro_Memphis_and_Charleston_Railroad_Depot', 'Meramec_State_Park_Lookout_House/Observation_Tower', 'Hendricks_County_Bridge_Number_316']
# ['', '', '', '', '', '', '', '', '', '']
# ['gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct', 'gb-sct']
# ['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['43908', '30102', '32691', '1799', '14988', '5135', '15774', '41140', '1946', '614']
# ['gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb']
# ['sct', 'sct', 'sct', 'sct', 'sct', 'sct', 'sct', 'sct', 'sct', 'sct']
# ['', '', '', '', '', '', '', '', '', '']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['32 India Street', '3 Kirklee Road and 1 Redlands Road', 'Russell House', '3-10 (Inclusive Nos) Crown Circus and 1, 1A and 2 Crown Terrace and 15 and 17 Crown Road North', 'Lochnaw, Walled Garden', 'Windyhill', 'Prestongrange Colliery, Pump House and Pump', '[[Crail Airfield]], Technical Area, Control Tower, No 62565 09048', '157-167 (Odd Nos) Hope Street and 169-175 (Odd Nos) West George Street', 'South African War Memorial']
# ['[[Renton, West Dunbartonshire|Renton]], Main Street', '[[Canongate]]', '', "St John's Road, [[Corstorphine]]", '[[Langholm]], carrying the [[A7 road (Great Britain)|A7]] over the [[River Esk, Dumfries and Galloway|River Esk]]', '', 'Royal Infirmary Forecourt, 1 Lauriston Place', 'Belford Road', '[[Gifford, East Lothian|Gifford]]', '[[Wick, Highland|Wick]]']
# ['', '', '', '', '', '', '', '', '', '']
# [55.956567999999997, 56.221352000000003, 55.956398999999998, 55.703214000000003, 57.019793999999997, 55.956702999999997, 55.608302000000002, 56.437012000000003, 57.731251, 57.644728000000001]
# [-3.202944, -3.1913330000000002, -5.0719940000000001, -1.7906070000000001, -3.1801759999999999, -4.8678330000000001, -3.3697759999999999, -3.4358979999999999, -4.4054970000000004, -2.7684920000000002]
# ['nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov', 'nl-prov']
# ['nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['NH/WN420', 'DR/PM1-0084', 'DR/PM1-0041', 'DR/PM1-0149', 'NH/WN594', 'NH/WN451', 'NH/WN173', 'DR/PM1-0190', 'NH/WN495', 'NH/WN496']
# ['nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl', 'nl']
# ['nl-dr', 'nl-dr', 'nl-dr', 'nl-nh', 'nl-nh', 'nl-dr', 'nl-nh', 'nl-nh', 'nl-dr', 'nl-nh']
# ['', '', '', '', '', '', '', '', '', '']
# ['Barsingerhorn', 'Ruinerwold', 'Schardam', 'Emmen', 'Ruinerwold', 'Schagerbrug', 'Westerland', 'Sint maartensvlotbrug', 'Velsen', 'Aerdenhout']
# [None, None, None, None, None, None, None, None, None, None]
# ['Dwarshuisboerderij', 'Landhuis/villa', 'Baarhuisje in ambachtelijk-traditionele stijl', '[[Noorder IJ- en Zeedijk]]: dijk', '[[Noorder IJ- en Zeedijk]]: dijk', 'Woonhuis', '{{sorteer|Rusthoek|De Rusthoek}}', '[[Stelling van Amsterdam]]: Nevenbatterij van fort Krommeniedijk', 'Woonhuis', '[[Noorder IJ- en Zeedijk]]: dijk']
# ['Kamerlingh Onneslaan 1', 'Schorweg 99', 'Fuikvaart bij Ringvaart', 'Vogelenzangseweg 21', '{{sorteer|Zuideinde 098|Zuideinde 98}}', '{{sorteer|Stationsweg 30|Stationsweg 30}}', 'Bentveldseduinweg 2', 'Dorpsstraat 32', 'De Buiksloterbreek', 'Zuiddijk 4']
# ['', '', '', '', '', '', '', '', '', '']
# [52.240554400000001, 52.8011956, 52.403375500000003, 52.700276600000002, nan, 52.671866100000003, 52.411163500000001, 52.665915200000001, 52.367102199999998, 52.934663499999999]
# [4.8920925999999998, 5.0675394999999996, 6.7081198999999998, 5.1317221999999996, 5.0708060000000001, 5.0171903000000002, 6.5609234000000001, 5.0627405000000003, 4.5990770899999998, 4.6060089]
# [1055.0, 1049.0, 1061.0, 1055.0, nan, 1047.0, 1056.0, 1053.0, 1050.0, 1056.0]
# [124.0, 102.0, 98.0, nan, 94.0, nan, 121.0, 94.0, 125.0, nan]
# ['', '', '', '', 'Exloerkijl69 Tweede Exloermond.jpg', 'Grenspaal Hoogwoud-Opmeer1.JPG', '', '', '', '']
# ['', '', '', '', '', '', 'Oude Rijksweg 10 (Vries)', '', '', '']
# ['http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=8178', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=11536', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=4474', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=65875', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=51198', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=13760', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=52053', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=36787', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=51024', 'http://denkxweb.denkmalpflege-hessen.de/cgi-bin/mapwalk.pl?event=Query.Details&obj=161965']
# ['tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn']
# ['fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'fr', 'fr']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['13-2', '11-11', '31-52', '11-110', '61-10', '11-146', '11-41', '21-11', '11-129', '33-14']
# ['tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn', 'tn']
# ['tn-31', 'tn-34', 'tn-11', 'tn-52', 'tn-21', '', 'tn-34', 'tn-11', 'tn-34', 'tn-42']
# ['Henchir Kachnoun', '[[Kairouan]]', 'Henchir el-Baroud', '[[Bulla Regia]]', '[[Aïn Tounga]]', '[[Kerkennah]]', '[[Ghar El Melh]]', 'Henchir Zakkar', 'Toukabeur', 'Aïn Trab']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['Ruines romaines dites « le Hammam »', 'Citernes juxtaposées, sur un contrefort du Jebel Bou-Krazt Talmed', '[[Basilique de Saint-Cyprien]] entre Sainte-Monique et Amilcar, sur le promontoire qui surplombe le ravin', '[[Dar El Haddad]]', 'Maison (Labérie)', 'Temple de Tanit transformé en basilique chrétienne', 'Mosquée', 'Sebil Bach Hamba', 'Ruines de la basilique proprement dite, placée au nord de la citadelle', 'Mausolée carré']
# ['5, rue Sidi Ali Ennouri', '', '', '', '', '', '', '', '', '']
# ['Rhiria', '[[Dougga]]', '[[Fériana]]', 'Fedj el-Kebara', '[[Tunis]]', 'Henchir Tamesmida', '[[Majel Bel Abbès]]', '[[Thuburnica]]', 'El Knatir', 'Houch el-Kheima']
# [35.677030000000002, 37.281129999999997, 36.797344000000002, nan, nan, nan, nan, 35.852922, nan, 35.818100000000001]
# [10.178189, 10.100942999999999, nan, nan, nan, 10.457897000000001, 9.9047920000000005, nan, 8.7591079999999994, nan]
# [nan, 717.0, nan, nan, 716.0, nan, nan, 736.0, 736.0, 737.0]
# [184.0, 207.0, nan, 222.0, 215.0, nan, 203.0, nan, 203.0, nan]
# ['', 'Barber Mosque Courtyard.jpg', '', 'Piliers 2.JPG', '', '', 'Medresa Slimania.jpg', '', '', '']
# ['', '', 'Fondouk des Français', '', '', 'Ancient Roman fountain in Téboursouk', 'Temple of Saturn, Dougga', 'Bridge over the Oued Cherchira', '', '']
# ['//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Sidi_Bouzid&oldid=118333554', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_B%C3%A9ja&oldid=125097755', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Kasserine&oldid=119003547', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_du_Kef&oldid=124592973', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Tunis&oldid=126055315', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Kairouan&oldid=123379092', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Sousse&oldid=118823715', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Tunis&oldid=126055315', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Kairouan&oldid=123379092', '//fr.wikipedia.org/w/index.php?title=Liste_des_monuments_class%C3%A9s_du_gouvernorat_de_Sousse&oldid=118823715']
# [numpy.datetime64('2016-06-08T16:39:34.000000000+0200'), numpy.datetime64('2016-06-08T16:39:22.000000000+0200'), numpy.datetime64('2016-06-08T16:39:16.000000000+0200'), numpy.datetime64('2016-06-08T16:39:38.000000000+0200'), numpy.datetime64('2016-06-08T16:39:16.000000000+0200'), numpy.datetime64('2016-06-08T16:39:38.000000000+0200'), numpy.datetime64('2016-06-08T16:39:24.000000000+0200'), numpy.datetime64('2016-06-08T16:39:26.000000000+0200'), numpy.datetime64('2016-06-08T16:39:38.000000000+0200'), numpy.datetime64('2016-06-08T16:39:32.000000000+0200')]
# ['', '', '', '', 'Tourbet_El_Bey', '', '', '', '', '']
# ['83-1', '34-41', '34-12', '31-5', '22-44', '32-23', '22-14', '11-37', '41-60', '51-10']
# ['pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa']
# ['es', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'es', 'es']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['03-027-DCMH', '08-065-DCMHN', '08-045-DCMHN', '08-117', '08-093-DCMHN', '08-122', '08-095-DCMHN', '08-047', '03-017-DCMH', '08-057-DCMHN']
# ['pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa', 'pa']
# ['pa-4', 'pa-8', 'pa-8', 'pa-8', 'pa-8', 'pa-7', 'pa-8', 'pa-8', 'pa-8', 'pa-8']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None,
es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_Hist%C3%B3ricos_de_Panam%C3%A1&oldid=89671803', '//es.wikipedia.org/w/index.php?title=Anexo%3AMonumentos_Hist%C3%B3ricos_de_Panam%C3%A1&oldid=89671803']
# [numpy.datetime64('2016-06-08T15:56:44.000000000+0200'), numpy.datetime64('2016-06-08T15:56:44.000000000+0200'), numpy.datetime64('2016-06-08T15:56:44.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200'), numpy.datetime64('2016-06-08T15:56:44.000000000+0200'), numpy.datetime64('2016-06-08T15:56:45.000000000+0200')]
# ['', '', 'Instituto Conmemorativo Gorgas', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '']
# ['ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch']
# ['fr', 'de', 'fr', 'de', 'de', 'fr', 'de', 'de', 'de', 'de']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['915C', 'HO4679', '13395', '15500637', '15300915', '01000482', '1523', '9702', '15803731', '08700031']
# ['ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch', 'ch']
# ['ch-zh', 'ch-zh', 'ch-gr', 'ch-zh', 'ch-sg', 'ch-nw', 'ch-gr', 'ch-vd', 'ch-zh', 'ch-zh']
# [None, None, None, None, None, None, None, None, None, None]
# ['Hausen am Albis', 'Luzern', 'Mönchaltorf', 'Unterschächen', 'Worb', 'Zürich', 'Lausanne', 'Ersigen', 'St. Gallen', 'Oberstammheim']
# [None, None, None, None, None, None, None, None, None, None]
# ['Bauernhaus', 'Pfarrkirche San Maurizio', 'Ehemaliges Gasthaus Hirschen', 'Bauernhof', 'Bahnhof Andelfingen, WC-Gebäude', 'Ehemaliger Speicher', 'Oratorium San Vigilio', 'Ehemalige Waschhäuser', 'Speicher Sieberslehn', 'Musée Romain']
# ['Rue Pierre-Aeby 16', 'Goldauerstrasse 10', 'Müllersberg', 'Alt-Rheinau 21', 'Rue de Lausanne 14', 'Predigerplatz 40', 'Landstrasse 40', 'Rue Haute 23', 'Steinmaurstrasse 16', 'Bim Zytglogge 1']
# ['Hägendorf', 'Zürich', 'Brig-Glis', 'Hirzel', 'Vezia', '', 'Genf', 'Acquarossa', 'Glattfelden', 'Hausen am Albis']
# [47.504330000000003, nan, 47.034619999999997, 46.223529999999997, 47.235135999999997, 47.512663000000003, 47.517513999999998, 47.016536000000002, 47.603363000000002, 47.190719999999999]
# [8.5247770000000003, 8.3795029999999997, 6.1261000000000001, 8.2497900000000008, 8.5792719999999996, 7.3161300000000002, 8.3165300000000002, nan, nan, 8.6059040000000007]
# [937.0, 934.0, 944.0, 945.0, 929.0, 944.0, 952.0, 949.0, 950.0, 936.0]
# [173.0, nan, 152.0, 149.0, nan, 168.0, 166.0, 184.0, 170.0, 178.0]
# ['', 'Trubschachen, Himmelhaus (1).jpg', '', '', 'HornTG01.jpg', '', '', 'KGS-Nr 6048.JPG', '', '']
# ['', 'Reformierte Kirche Wetzikon', '', 'Tennisanlage Geiselweid', '', "House rue d'Or 7, Fribourg", '', 'Usine électrique, La Chaux-de-Fonds', 'Pfarrkirche Heilige Dreifaltigkeit (Unterbäch)', 'Vevey']
ikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['376-37903-1', '390-21418-32', '561-147906-3', '727-52569-1', '400-183856-2', '259-53781-1', '580-20926-1', '851-631790-3', '217-43506-1', '330--1--1']
# ['dk', 'dk', 'dk', 'dk', 'dk', 'dk', 'dk', 'dk', 'dk', 'dk']
# ['dk-82', 'dk-84', 'dk-83', 'dk-83', 'dk-84', 'dk-84', 'dk-83', 'dk-83', 'dk-84', 'dk-85']
# ['[[Københavns Kommune]]', '[[Egedal Kommune]]', '[[Københavns Kommune]]', '[[Nordfyns Kommune]]', '[[Københavns Kommune]]', '[[Haderslev Kommune]]', '[[Københavns Kommune]]', '[[Dragør Kommune]]', '[[Bornholms Regionskommune]]', '[[Odense Kommune]]']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['Holmen', 'Bakkehusene, Markvej', 'Hellerup Station', 'Den Treschowske Stiftelse', 'Ved Stranden 16', 'Centralværkstederne, administrationsbygning m.m.', 'Annebergparken', 'Tuxens Hus, Skagen', 'Grønnemose Allé 21 A-G', 'Birkely']
# ['Hesnæsvej 56', 'Mejlgade 45', 'Birkevej 17C', 'Hovej 21', 'Stormgade 8', 'Bakkedraget 10', 'Overdammen 10', 'Ullerslevvej 42', 'Tuxens Alle 18A', 'Nybrovej 47']
# ...
# [numpy.datetime64('2016-06-08T08:52:28.000000000+0200'), numpy.datetime64('2016-06-08T08:52:28.000000000+0200'), numpy.datetime64('2016-06-08T08:52:05.000000000+0200'), numpy.datetime64('2016-06-08T08:51:49.000000000+0200'), numpy.datetime64('2016-06-08T08:52:22.000000000+0200'), numpy.datetime64('2016-06-08T08:52:07.000000000+0200'), numpy.datetime64('2016-06-08T08:52:16.000000000+0200'), numpy.datetime64('2016-06-08T08:52:11.000000000+0200'), numpy.datetime64('2016-06-08T08:52:21.000000000+0200'), numpy.datetime64('2016-06-08T08:52:14.000000000+0200')]
# ['Ada_Blocks_hus', 'Vatlings', 'Kvarteret_Skogen', 'Victoriafortet', 'Vallda_kyrka', 'Residenset_i_Falun', 'Törnevalla_kyrka', 'Den_gode_herdens_kyrka,_Helsingborg', 'Örnäsets_kyrka', 'Skansen_Kronan']
# ['http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000010974', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000003689', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000002276', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000004212', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000005375', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000003093', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000003144', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000005833', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000013125', 'http://www.bebyggelseregistret.raa.se/bbr2/anlaggning/visaHistorik.raa?page=historik&visaHistorik=true&anlaggningId=21300000011544']
# ['gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng', 'gb-eng']
# ['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['1309508', '1194053', '1235979', '1002474', '1105769', '1281495', '1172038', '1071232', '1044134', '1218277']
# ['gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb', 'gb']
# ['eng', 'eng', 'eng', 'eng', 'eng', 'eng', 'eng', 'eng', 'eng', 'eng']
# ['gb-ery', 'gb-nth', 'gb-wbk', '', 'gb-dor', 'gb-hil', 'gb-sts', 'gb-cbf', 'gb-dev', 'gb-wor']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['The Manor House', 'Summer House in Garden of No 15, The Close', 'Lanehouse Farmhouse', '[[Heaton Park#Temple|Heaton Park Temple]]', 'Burden Court Farmhouse and Gate Piers 10m to South West', '[[Dunham Massey|Dunham Massey sawmill]]', 'Rayrigg Hall Farmhouse', '[[Dove Cottage]]', '[[Coventry city walls|Swanswell Gate and city wall to the north]]', 'The Clock House']
# ['Melton Constable Park, Melton Constable', "38 St Oswald's Place, Kennington", '[[Winterborne Stickland]]', 'Burley on the Hill, Burley, Rutland', 'Ewe Cote, Whitby, Scarborough', '[[Clitheroe]]', 'Stamford, South Kesteven', 'Featherstone, Northumberland', 'Salisbury', '[[Penge]]/Beckenham']
# ['gb-skp', 'gb-sfk', 'gb-gls', 'gb-oxf', 'gb-ess', 'gb-con', 'gb-cam', 'gb-gls', 'gb-con', 'gb-con']
# [52.708626000000002, 51.856887999999998, 52.050224, 50.712794000000002, 52.790007000000003, 51.750225, 51.059600000000003, 51.312477999999999, 51.506310999999997, 51.512965999999999]
# [-0.2122, -3.8091200000000001, -1.4752369999999999, 1.481007, -2.6402510000000001, -0.95725899999999997, -2.6776740000000001, -1.839969, -0.86982099999999996, -1.5688679999999999]
# [1016.0, 1013.0, 1092.0, 1017.0, 1016.0, 1009.0, 1027.0, 1022.0, 1036.0, 1037.0]
# [-18.0, -73.0, -55.0, -10.0, -8.0, -41.0, -55.0, -5.0, 13.0, -24.0]
# ['St Michaels church, East Anstey (geograph 3217144).jpg', 'Badgworthy Water Malmsmead.jpg', 'Manor House Farm, Stoke St Michael - geograph.org.uk - 137650.jpg', 'All Saints Church, Wighton - geograph.org.uk - 1065008.jpg', '', 'Hoglands, Perry Green.JPG', 'Court Lodge Barn Mersham Geograph-1889972-by-David-Anstiss.jpg', '', '', 'Gallox Bridge.jpg']
# ["St Nicholas' church, Uphill, Somerset", '', '', 'All Saints, Babworth', 'All Saints, Hilgay', '', '', '', '', "St Anne's Church, Denton"]
index.php?title=Liste_der_Baudenkm%C3%A4ler_in_Paffendorf&oldid=126722949', '//de.wikipedia.org/w/index.php?title=Liste_der_Baudenkm%C3%A4ler_in_Quadrath-Ichendorf&oldid=123965971', '//de.wikipedia.org/w/index.php?title=Liste_der_Baudenkm%C3%A4ler_in_Oberau%C3%9Fem&oldid=154629918', '//de.wikipedia.org/w/index.php?title=Liste_der_Baudenkm%C3%A4ler_in_Fliesteden&oldid=151630847']
# [numpy.datetime64('2016-06-08T08:46:34.000000000+0200'), numpy.datetime64('2016-06-08T08:46:41.000000000+0200'), numpy.datetime64('2016-06-08T08:46:35.000000000+0200'), numpy.datetime64('2016-06-08T08:46:40.000000000+0200'), numpy.datetime64('2016-06-08T08:46:43.000000000+0200'), numpy.datetime64('2016-06-08T08:46:38.000000000+0200'), numpy.datetime64('2016-06-08T08:46:30.000000000+0200'), numpy.datetime64('2016-06-08T08:46:41.000000000+0200'), numpy.datetime64('2016-06-08T08:46:44.000000000+0200'), numpy.datetime64('2016-06-08T08:46:30.000000000+0200')]
# ['', '', '', '', '', '', '', '', 'Sankt-Pankratius-Kirche_(Paffendorf)', 'St._Remigius_(Bergheim)']
# ['', '', '', '', '', '', '', '', '', '']
# ['gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh']
# ['en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en', 'en']
# ['wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia', 'wikipedia']
# ['GH-AH-004', 'GH-NP-001', 'GH-AA-007', 'GH-CP-008', 'GH-AA-002', 'GH-AH-006', 'GH-CP-005', 'CE-GH-CP-00', 'GH-EP-001', 'GH-AA-001']
# ['gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh', 'gh']
# ['gh_ah', 'gh-aa', 'gh-cp', 'gh-wp', 'gh-aa', 'gh-aa', 'gh-cp', 'gh_ah', 'gh-cp', 'gh_np']
# ['[[Nzema]]', '[[Old Ningo]]', '[[Shama, Ghana|Shama]]', '[[University of Ghana]], Department of Archeology, [[Accra]]', '[[Cape Coast]]', 'Ejisu-Besease', '[[Abirem]]', '[[Asawase]] near Ejisu', '[[Elmina]]', '[[Saaman]]']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# ['Kumasi Military Museum', '[[Fort Santo Antonio|Fort Saint Anthony]]', 'Kentinkrono Shrine', '[[Fort Lijdzaamheid]]', 'The Little Fort', '[[Fort Vredenburgh|Fort Vredenburg]]', 'Fort Fredericksburg', 'Fort Augustaborg', 'Fort Kumasi', 'Volta Regional Museum']
# ['', '', '', '', '', '', '', '', '', '']
# ['[[Princes Town, Ghana|Princestown]]', '[[Shama, Ghana|Shama]]', '[[Axim]]', '[[Cape Coast]]', '[[Butre]]', '[[Old Ningo]]', '[[Dixcove]]', '[[Moree, Ghana|Moree]]', '[[Beyin]]', '[[Nzema]]']
# [nan, 5.1666999999999996, 5.2024999999999997, nan, 5.0833329999999997, 5.1050560000000003, 4.9356999999999998, 5.0833329999999997, 5.0833329999999997, nan]
# [nan, nan, -1.247234, -1.7073, -1.1089244, -1.9211483, -1.3500000000000001, nan, nan, nan]
# [nan, 95.0, 102.0, nan, 115.0, 134.0, 108.0, nan, nan, nan]
# [-22.0, nan, -32.0, nan, -4.0, nan, nan, -25.0, nan, nan]
# ['Overzicht voorgevel met bordes binnen de buitenmuur - Apam - 20375240 - RCE.jpg', 'FortsSekondi.JPG', '', '', '', 'Ussher Fort.JPG', 'Butre Litho 1709.png', 'Fort St. Jago.JPG', 'Anomabucastle.jpg', '']
# ['', '', '', '', '', '', '', 'Larabanga Mosque', '', '']
# ['//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059', '//en.wikipedia.org/w/index.php?title=Ghana%27s_material_cultural_heritage&oldid=713407059']
# [numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200'), numpy.datetime64('2016-06-08T14:15:42.000000000+0200')]
# ['Fort_Victoria_(Ghana)', 'Osu_Castle', '', 'Fort_Vredenburgh', 'Fort_Goede_Hoop_(Ghana)', 'Ussher_Fort', 'Fort_Batenstein', 'Fort_Santo_Antonio', '', 'Fort_Lijdzaamheid']
# ['', '', '', '', '', '', '', '', '', '']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-beacca89b8e4> in <module>()
#       4     for column in columns:
#       5         values = country[column]
# ----> 6         sample = values.sample(n=10)
#       7         examples = sample.values
#       8         #print(code, column, values.sample(n=3))
#
# /home/mos/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    2567                              "provide positive value.")
#    2568
# -> 2569         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    2570         return self.take(locs, axis=axis, is_copy=False)
#    2571
#
# mtrand.pyx in mtrand.RandomState.choice (numpy/random/mtrand/mtrand.c:12517)()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
def create_column_tables(df):
    """Takes a Pandas DataFrame object and writes wikitables to files named after the table they are
    produced from to {the current Directory}/wikitables/
    """
    country_codes = dict(df.country.value_counts()).keys()
    for code in country_codes:
        h1 = "= Non-standardized fields from country " + code + " in monuments_all =\n"
        column_tables = [] 
        country = df[df["country"] == code]
        columns = country.columns
        page_sections = []
        for column in columns:
            # the listed fields we avoid are assumed to be standardized
            if column not in ["country","lang","project","changed","lat","lon","lat_int","lon_int"]:
                h2 = "== 10 random samples from field " + column + " ==\n"
                values = country[column]
                try:
                    sample = values.sample(n=10)
                    examples = sample.values
                except ValueError as e:
                    print("country: {} cannot be sampled: {}. Total objects is {}. Skipping country.".format(code, len(values), e))
                    break
    
                table_header = '{| class="wikitable" style="width: 675px;\n'
                table_name = '|+ '+code + "-" + column + " 10 random samples\n"
            
                # create table columns
                table_columns = "! scope='col' style='width: 225px;' |" + str(column) + "\n" + \
                "! scope='col' style='width: 225px; height: 20px;'|" + "Conversion \n" + \
                "! scope='col' style='width: 225px;' | Comment\n|-\n"
                
                table_rows = []
            
                for example in examples:
                    row="| style='height: 20px;'| " + str(example) + "\n|\n|\n|-\n"
                    table_rows.append(row)
    
                    table_rows_str = "".join(table_rows)
                    # Fill in examples values from the first record in the table
                    table_footer = "\n|}"
            else:
                continue
            
            column_tables.append(h2)    
            column_table = table_header + table_name + table_columns + table_rows_str[:-1] + table_footer
            column_tables.append(column_table)
            
        
        wikipage = h1 + "\n".join(column_tables)
        
        if os.path.isdir("./files"):
            #print(wikipage)
            out = open("./files/" + code + ".columntables","w")
            out.write(wikipage)
            out.flush()
            print("Directory ./files exists. Wrote file {}".format(out.name))
            out.close()
            
        else:
            os.mkdir("./files")
            with open("./files/" + code + ".columntables","w") as out:
                out.write(wikipage)
                print("./files doesn't exist")

# %%
create_column_tables(df)
# Out:
# Directory ./files exists. Wrote file ./files/be-wal.columntables
# Directory ./files exists. Wrote file ./files/bo.columntables
# Directory ./files exists. Wrote file ./files/us.columntables
# Directory ./files exists. Wrote file ./files/gb-sct.columntables
# Directory ./files exists. Wrote file ./files/nl-prov.columntables
# Directory ./files exists. Wrote file ./files/de-he.columntables
# Directory ./files exists. Wrote file ./files/tn.columntables
# Directory ./files exists. Wrote file ./files/pa.columntables
# Directory ./files exists. Wrote file ./files/ch.columntables
# Directory ./files exists. Wrote file ./files/aq.columntables
# Directory ./files exists. Wrote file ./files/dk-bygning.columntables
# Directory ./files exists. Wrote file ./files/be-vlg.columntables
# Directory ./files exists. Wrote file ./files/az.columntables
# Directory ./files exists. Wrote file ./files/ca.columntables
# Directory ./files exists. Wrote file ./files/se-arbetsl.columntables
# Directory ./files exists. Wrote file ./files/it-88.columntables
# Directory ./files exists. Wrote file ./files/hk.columntables
# Directory ./files exists. Wrote file ./files/cz.columntables
# Directory ./files exists. Wrote file ./files/no.columntables
# Directory ./files exists. Wrote file ./files/at.columntables
# Directory ./files exists. Wrote file ./files/ve.columntables
# Directory ./files exists. Wrote file ./files/fr-object.columntables
# Directory ./files exists. Wrote file ./files/in.columntables
# Directory ./files exists. Wrote file ./files/be-bru.columntables
# Directory ./files exists. Wrote file ./files/se-fornmin.columntables
# Directory ./files exists. Wrote file ./files/dk-fortids.columntables
# Directory ./files exists. Wrote file ./files/lu.columntables
# Directory ./files exists. Wrote file ./files/nl-gem.columntables
# Directory ./files exists. Wrote file ./files/ad.columntables
# Directory ./files exists. Wrote file ./files/se-bbr.columntables
# Directory ./files exists. Wrote file ./files/gb-eng.columntables
# Directory ./files exists. Wrote file ./files/de-nrw-bm.columntables
# Directory ./files exists. Wrote file ./files/gh.columntables
# country: cm cannot be sampled: 1. Total objects is Cannot take a larger sample than population when 'replace=False'. Skipping country.
# Directory ./files exists. Wrote file ./files/cm.columntables
# Directory ./files exists. Wrote file ./files/it.columntables
# Directory ./files exists. Wrote file ./files/cl.columntables
# Directory ./files exists. Wrote file ./files/us-ca.columntables
# Directory ./files exists. Wrote file ./files/ro.columntables
# Directory ./files exists. Wrote file ./files/pt.columntables
# Directory ./files exists. Wrote file ./files/am.columntables
# Directory ./files exists. Wrote file ./files/nl-aw.columntables
# Directory ./files exists. Wrote file ./files/il.columntables
# Directory ./files exists. Wrote file ./files/pk.columntables
# Directory ./files exists. Wrote file ./files/jo.columntables
# Directory ./files exists. Wrote file ./files/ch-old.columntables
# Directory ./files exists. Wrote file ./files/cn.columntables
# Directory ./files exists. Wrote file ./files/gb-wls.columntables
# Directory ./files exists. Wrote file ./files/ua.columntables
# Directory ./files exists. Wrote file ./files/ru.columntables
# Directory ./files exists. Wrote file ./files/nl.columntables
# Directory ./files exists. Wrote file ./files/th.columntables
# Directory ./files exists. Wrote file ./files/fr.columntables
# Directory ./files exists. Wrote file ./files/uy.columntables
# Directory ./files exists. Wrote file ./files/za.columntables
# Directory ./files exists. Wrote file ./files/sv.columntables
# Directory ./files exists. Wrote file ./files/it-bz.columntables
# Directory ./files exists. Wrote file ./files/ph.columntables
# Directory ./files exists. Wrote file ./files/es.columntables
# Directory ./files exists. Wrote file ./files/de-by.columntables
# Directory ./files exists. Wrote file ./files/dz.columntables
# Directory ./files exists. Wrote file ./files/se-ship.columntables
# Directory ./files exists. Wrote file ./files/ke.columntables
# Directory ./files exists. Wrote file ./files/mt.columntables
# Directory ./files exists. Wrote file ./files/ee.columntables
# Directory ./files exists. Wrote file ./files/co.columntables
# Directory ./files exists. Wrote file ./files/rs.columntables
# Directory ./files exists. Wrote file ./files/ar.columntables
# Directory ./files exists. Wrote file ./files/pl.columntables
# Directory ./files exists. Wrote file ./files/by.columntables
# Directory ./files exists. Wrote file ./files/ie.columntables
# Directory ./files exists. Wrote file ./files/np.columntables
# Directory ./files exists. Wrote file ./files/hu.columntables
# Directory ./files exists. Wrote file ./files/jp-nhs.columntables
# Directory ./files exists. Wrote file ./files/mx.columntables
# Directory ./files exists. Wrote file ./files/de-nrw-k.columntables
# Directory ./files exists. Wrote file ./files/sk.columntables
# Directory ./files exists. Wrote file ./files/gb-nir.columntables
